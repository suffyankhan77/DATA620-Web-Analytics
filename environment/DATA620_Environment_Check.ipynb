# %%
import sys
print("Python:", sys.version)
# Out:
# Python: 3.7.16 (default, Jan 17 2023, 16:06:28) [MSC v.1916 64 bit (AMD64)]

# %%
import networkx as nx
print("NetworkX:", nx.__version__)
# Out:
# NetworkX: 1.11

# %%
import nltk
print("NLTK:", nltk.__version__)
# Out:
# NLTK: 3.7

# %%
import pandas as pd
print("Pandas:", pd.__version__)
# Out:
# Pandas: 1.3.5

# %%
import numpy as np
print("NumPy:", np.__version__)
# Out:
# NumPy: 1.21.5

# %%
import matplotlib
print("Matplotlib:", matplotlib.__version__)
# Out:
# Matplotlib: 3.5.3

# %%
import sklearn
print("Scikit-learn:", sklearn.__version__)
# Out:
# Scikit-learn: 1.0.2

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a simple graph
G = nx.Graph()

# Add nodes
G.add_node("Hello")
G.add_node("Graph")
G.add_node("World")

# Add edges
G.add_edge("Hello", "Graph")
G.add_edge("Graph", "World")
G.add_edge("World", "Hello")

# Print basic graph information
print("Number of nodes:", G.number_of_nodes())
print("Number of edges:", G.number_of_edges())
print("Nodes:", G.nodes())
print("Edges:", G.edges())

# Draw the graph
nx.draw(G, with_labels=True, node_size=2000, font_size=12)
plt.show()
# Out:
# Number of nodes: 3
# Number of edges: 3
# Nodes: ['Hello', 'Graph', 'World']
# Edges: [('Hello', 'Graph'), ('Hello', 'World'), ('Graph', 'World')]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22268\977749961.py in <module>
#      22
#      23 # Draw the graph
# ---> 24 nx.draw(G, with_labels=True, node_size=2000, font_size=12)
#      25 plt.show()
#
# ~\anaconda3\envs\sps620env\lib\site-packages\networkx\drawing\nx_pylab.py in draw(G, pos, ax, hold, **kwds)
#     124     if 'with_labels' not in kwds:
#     125         kwds['with_labels'] = 'labels' in kwds
# --> 126     b = plt.ishold()
#     127     # allow callers to override the hold state by passing hold=True|False
#     128     h = kwds.pop('hold', None)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ishold'
